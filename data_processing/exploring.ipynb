# %%
# Run pip install c3d

# %%
import c3d

# %%
#Please change the URL
with open('C:\\Users\\sakhn\\Downloads\\gait_data\\data\\2014001\\2014001_ST.c3d', 'rb') as handle:
    reader = c3d.Reader(handle)
    for item in reader.read_frames():
        print(item)
# Out:
# (1, array([[ 796.59460449,  358.7026062 ,  878.23944092,    0.        ,
#            0.        ],
#        [ 618.09399414,  287.34094238,  920.25598145,    0.        ,
#            0.        ],
#        [ 612.28198242,  197.71774292,  920.52111816,    0.        ,
#            0.        ],
#        [ 786.8326416 ,  115.86606598,  887.84344482,    0.        ,
#            0.        ],
#        [ 712.37188721,  416.2557373 ,  799.19256592,    0.        ,
#            0.        ],
#        [ 690.44989014,  421.64456177,  447.75546265,    0.        ,
#            0.        ],
#        [ 709.32336426,  307.83544922,  421.68106079,    0.        ,
#            0.        ],
#        [ 667.18530273,  431.90560913,  390.81918335,    0.        ,
#            0.        ],
#        [ 726.52087402,  386.79467773,  362.08111572,    0.        ,
#            0.        ],
#        [ 649.93701172,  428.70922852,   67.26460266,    0.        ,
#            0.        ],
# ...
